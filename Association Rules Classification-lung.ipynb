# %%
# !pip install mlxtend  
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules
# Out:
# Requirement already satisfied: mlxtend in c:\users\anoop\anaconda3\lib\site-packages (0.22.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\anoop\anaconda3\lib\site-packages (from mlxtend) (1.4.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\anoop\anaconda3\lib\site-packages (from mlxtend) (1.0.2)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\anoop\anaconda3\lib\site-packages (from mlxtend) (1.21.5)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\anoop\anaconda3\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: setuptools in c:\users\anoop\anaconda3\lib\site-packages (from mlxtend) (63.4.1)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\anoop\anaconda3\lib\site-packages (from mlxtend) (1.9.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\anoop\anaconda3\lib\site-packages (from mlxtend) (3.5.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anoop\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\anoop\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\anoop\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anoop\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\anoop\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\anoop\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anoop\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anoop\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anoop\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\anoop\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
data = pd.read_csv(r"C:\Users\anoop\Downloads\lung_cancer1.csv.csv")

# %%
data = data.replace({'YES': 2, 'NO': 1})
data = data.replace({'M': 2, 'F': 1})

# %%
data.head()
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0       2   69        1               2        2              1
# 1       2   74        2               1        1              1
# 2       1   59        1               1        1              2
# 3       2   63        2               2        2              1
# 4       1   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  LUNG_CANCER
# 0                    2                      2           2            2
# 1                    2                      2           2            2
# 2                    2                      1           2            1
# 3                    1                      2           2            1
# 4                    2                      1           1            1

# %%
data.shape
# Out:
# (309, 16)

# %%
data = list(data["LUNG_CANCER"].apply(lambda x: str(x).split(",")))
data
# Out:
# [['2'],
#  ['2'],
#  ['1'],
#  ['1'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['1'],
#  ['1'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['1'],
#  ['2'],
#  ['1'],
#  ['1'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['1'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['1'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2'],
#  ['2']]

# %%
from mlxtend.preprocessing import TransactionEncoder
a = TransactionEncoder()
a_data = a.fit(data).transform(data)
df = pd.DataFrame(a_data, columns = a.columns_)
df=df.replace(False,0)
df=df.replace(True,1)
df
# Out:
#      1  2
# 0    0  1
# 1    0  1
# 2    1  0
# 3    1  0
# 4    1  0
# ..  .. ..
# 304  0  1
# 305  0  1
# 306  0  1
# 307  0  1
# 308  0  1
#
# [309 rows x 2 columns]

# %%
df = df.astype(bool)
df=apriori(df, min_support=0.2, use_colnames = True, verbose = 1)
df
# Out:
#     support itemsets
# 0  0.873786      (2)
